# %%
# Importing libraries 
import json
import os
import numpy as np
import cv2
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from PIL import Image
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
# Creating mask function
def create_mask(image_shape, shape_attributes):
    mask = np.zeros(image_shape, dtype=np.uint8)
    
    if shape_attributes['name'] == 'polygon':
        points_x = shape_attributes['all_points_x']
        points_y = shape_attributes['all_points_y']
        points = np.array(list(zip(points_x, points_y)), dtype=np.int32)
        cv2.fillPoly(mask, [points], 1)
    
    elif shape_attributes['name'] == 'ellipse':
        center_x = int(shape_attributes['cx'])
        center_y = int(shape_attributes['cy'])
        radius_x = int(shape_attributes['rx'])
        radius_y = int(shape_attributes['ry'])
        angle = shape_attributes.get('theta', 0) * (180.0 / np.pi)  # Convert radians to degrees
        cv2.ellipse(mask, (center_x, center_y), (radius_x, radius_y), angle, 0, 360, 1, -1)
    
    return mask

# %%
class BrainTumorDataset(Dataset):
    def __init__(self, json_file, root_dir, image_transform=None, mask_transform=None):
        self.root_dir = root_dir
        self.image_transform = image_transform
        self.mask_transform = mask_transform
        
        try:
            with open(json_file) as f:
                self.data = json.load(f)
        except FileNotFoundError:
            raise FileNotFoundError(f"JSON file '{json_file}' not found.")

        self.image_keys = list(self.data.keys())
        print(f"Loaded {len(self.image_keys)} entries from JSON file.")
        
    def __len__(self):
        return len(self.image_keys)

    def __getitem__(self, idx):
        image_key = self.image_keys[idx]
        image_info = self.data[image_key]

        file_name = image_info['filename']
        file_path = os.path.join(self.root_dir, file_name)

        try:
            image = Image.open(file_path).convert("RGB")
        except Exception as e:
            print(f"Error loading image '{file_name}': {e}")
            return None

        original_size = image.size  # (width, height)

        regions = image_info['regions']
        mask = np.zeros((original_size[1], original_size[0]), dtype=np.uint8)  # Initialize mask with zeros

        for region in regions:
            shape_attributes = region['shape_attributes']
            mask = np.maximum(mask, create_mask((original_size[1], original_size[0]), shape_attributes))

        mask = Image.fromarray(mask)

        if self.image_transform:
            image = self.image_transform(image)
        if self.mask_transform:
            mask = self.mask_transform(mask)
        else:
            mask = transforms.ToTensor()(mask)

        return image, mask

# %%
# Define transformations
image_transform = transforms.Compose([
    transforms.Resize((224, 224)),  
    transforms.ToTensor(),          
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

mask_transform = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.ToTensor(),
])

# %%
# Path to the JSON file containing annotations
root_dir = 'TRAIN'
json_file_path = os.path.join(root_dir, "annotations_train.json")

# Create dataset and dataloader for training using data from the TRAIN folder
train_dataset = BrainTumorDataset(json_file_path, root_dir, image_transform=image_transform, mask_transform=mask_transform)
train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)

# Debugging the data loading process
for i, data in enumerate(train_dataloader):
    if data is not None:
        images, masks = data
        if images is None or masks is None:
            continue  
        print(f"Batch {i}: Images shape: {images.shape}, Masks shape: {masks.shape}")
# Out:
# Loaded 500 entries from JSON file.
# Batch 0: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 1: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 2: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 3: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 4: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 5: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 6: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 7: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 8: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 9: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 10: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 11: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 12: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 13: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 14: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 15: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 16: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 17: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 18: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 19: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 20: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 21: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 22: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 23: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 24: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 25: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 26: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 27: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 28: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 29: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 30: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 31: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 32: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 33: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 34: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 35: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 36: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 37: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 38: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 39: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 40: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 41: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 42: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 43: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 44: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 45: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 46: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 47: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 48: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 49: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 50: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 51: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 52: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 53: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 54: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 55: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 56: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 57: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 58: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 59: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 60: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 61: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 62: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 63: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 64: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 65: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 66: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 67: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 68: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 69: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 70: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 71: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 72: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 73: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 74: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 75: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 76: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 77: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 78: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 79: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 80: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 81: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 82: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 83: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 84: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 85: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 86: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 87: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 88: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 89: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 90: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 91: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 92: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 93: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 94: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 95: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 96: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 97: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 98: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 99: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 100: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 101: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 102: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 103: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 104: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 105: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 106: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 107: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 108: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 109: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 110: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 111: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 112: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 113: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 114: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 115: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 116: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 117: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 118: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 119: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 120: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 121: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 122: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 123: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])
# Batch 124: Images shape: torch.Size([4, 3, 224, 224]), Masks shape: torch.Size([4, 1, 224, 224])

# %%
# Load the ResNeXt model
resnext = models.resnext50_32x4d(pretrained=True)
# Out:
# C:\Users\Amlan Anupam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Amlan Anupam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNeXt50_32X4D_Weights.IMAGENET1K_V1`. You can also use `weights=ResNeXt50_32X4D_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnext50_32x4d-7cdf4587.pth" to C:\Users\Amlan Anupam/.cache\torch\hub\checkpoints\resnext50_32x4d-7cdf4587.pth
# 100%|█████████████████████████████████████████████████████████████████████████████| 95.8M/95.8M [00:41<00:00, 2.41MB/s]

# %%
class ResNeXtSegmentation(nn.Module):
    def __init__(self, num_classes=1):
        super(ResNeXtSegmentation, self).__init__()
        self.resnext = models.resnext50_32x4d(pretrained=True)
        self.resnext_features = nn.Sequential(*list(self.resnext.children())[:-2])  # Extract the feature layers
        self.conv1 = nn.Conv2d(2048, 1024, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(1024, 512, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(512, num_classes, kernel_size=1)
        self.upsample = nn.Upsample(scale_factor=32, mode='bilinear', align_corners=False)

    def forward(self, x):
        x = self.resnext_features(x)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = self.conv3(x)
        x = self.upsample(x)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = ResNeXtSegmentation(num_classes=1).to(device)

# %%
import torch.nn.functional as F

# Define Dice loss
def dice_loss(pred, target, smooth=1.0):
    pred = pred.contiguous()
    target = target.contiguous()

    intersection = (pred * target).sum(dim=2).sum(dim=2)
    dice = (2. * intersection + smooth) / (pred.sum(dim=2).sum(dim=2) + target.sum(dim=2).sum(dim=2) + smooth)

    return 1 - dice.mean()

# Combined BCE and Dice loss
class BCEDiceLoss(nn.Module):
    def __init__(self):
        super(BCEDiceLoss, self).__init__()

    def forward(self, pred, target):
        bce = F.binary_cross_entropy_with_logits(pred, target)
        pred = torch.sigmoid(pred)
        dice = dice_loss(pred, target)
        return bce + dice

# %%
# Define loss function and optimizer
criterion = BCEDiceLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Training loop
num_epochs = 30
model.train()

for epoch in range(num_epochs):
    running_loss = 0.0
    for data in train_dataloader:
        if data is None:
            continue
        images, masks = data
        images = images.to(device)
        masks = masks.to(device)

        # Forward pass
        outputs = model(images)
        
        # Compute loss
        loss = criterion(outputs, masks)
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_dataloader)}")
# Out:
# Epoch [1/30], Loss: 0.8923065915107727
# Epoch [2/30], Loss: 0.8776737675666809
# Epoch [3/30], Loss: 0.8769736347198487
# Epoch [4/30], Loss: 0.8768728189468383
# Epoch [5/30], Loss: 0.8768418855667114
# Epoch [6/30], Loss: 0.8768113303184509
# Epoch [7/30], Loss: 0.8767803292274475
# Epoch [8/30], Loss: 0.8767394661903382
# Epoch [9/30], Loss: 0.8767493348121643
# Epoch [10/30], Loss: 0.8767330284118653
# Epoch [11/30], Loss: 0.8767176094055176
# Epoch [12/30], Loss: 0.8767222137451172
# Epoch [13/30], Loss: 0.8767059469223022
# Epoch [14/30], Loss: 0.8767002010345459
# Epoch [15/30], Loss: 0.8767019672393799
# Epoch [16/30], Loss: 0.8766982989311218
# Epoch [17/30], Loss: 0.8766958956718445
# Epoch [18/30], Loss: 0.8766888890266419
# Epoch [19/30], Loss: 0.8766864190101623
# Epoch [20/30], Loss: 0.87668168592453
# Epoch [21/30], Loss: 0.8766784701347351
# Epoch [22/30], Loss: 0.8766861162185668
# Epoch [23/30], Loss: 0.8766874008178711
# Epoch [24/30], Loss: 0.8766963796615601
# Epoch [25/30], Loss: 0.8766980609893799
# Epoch [26/30], Loss: 0.8766966810226441
# Epoch [27/30], Loss: 0.8766932682991028
# Epoch [28/30], Loss: 0.8766898531913757
# Epoch [29/30], Loss: 0.8767039012908936
# Epoch [30/30], Loss: 0.8767313537597656

# %%
# Save the model
torch.save(model.state_dict(), 'resnext_segmentation.pth')

# %%
# Visualization and IoU calculation functions
def calculate_iou(preds, masks, threshold=0.5):
    preds = preds > threshold
    masks = masks > threshold  # Ensure masks are binary
    intersection = (preds & masks).float().sum((1, 2))  # Intersection area
    union = (preds | masks).float().sum((1, 2))        # Union area
    iou = (intersection + 1e-6) / (union + 1e-6)       # IoU calculation
    return iou.mean().item()

def visualize_images(image, mask, prediction):
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))

    image = image.squeeze().permute(1, 2, 0).cpu().numpy()
    mask = mask.squeeze().cpu().numpy()
    prediction = prediction.squeeze().cpu().numpy()

    axes[0].imshow(image)
    axes[0].set_title("Original Image")
    axes[0].axis("off")

    axes[1].imshow(mask, cmap="gray")
    axes[1].set_title("Ground Truth Mask")
    axes[1].axis("off")

    axes[2].imshow(prediction, cmap="gray")
    axes[2].set_title("Predicted Mask")
    axes[2].axis("off")

    plt.show()

# %%
iou_scores_train = []

with torch.no_grad():
    model.eval()
    for images, masks in train_dataloader:
        images = images.to(device)
        masks = masks.to(device)

        outputs = model(images)
        predictions = torch.sigmoid(outputs)

        for i in range(len(images)):
            iou = calculate_iou(predictions[i], masks[i])
            iou_scores_train.append(iou)

average_iou_train = sum(iou_scores_train) / len(iou_scores_train)
print(f"Average IoU for the training set: {average_iou_train:.4f}")
# Out:
# Average IoU for the training set: 1.0000

# %%
# Visualize some images from the training set
num_images_to_visualize_train = 3

with torch.no_grad():
    model.eval()
    for i, (image, mask) in enumerate(train_dataloader):
        if i >= num_images_to_visualize_train:
            break

        image = image.to(device)
        outputs = model(image)
        prediction = torch.sigmoid(outputs)

        visualize_images(image[0], mask[0], prediction[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Test the model and calculate IoU for the validation set
root_dir = 'VAL'
json_file_path = os.path.join(root_dir, "annotations_val.json")

val_dataset = BrainTumorDataset(json_file_path, root_dir, image_transform=image_transform, mask_transform=mask_transform)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False)

iou_scores = []

with torch.no_grad():
    model.eval()
    for images, masks in val_loader:
        images = images.to(device)
        masks = masks.to(device)

        outputs = model(images)
        predictions = torch.sigmoid(outputs)

        for i in range(len(images)):
            iou = calculate_iou(predictions[i], masks[i])
            iou_scores.append(iou)

average_iou = sum(iou_scores) / len(iou_scores)
print(f"Average IoU for the validation set: {average_iou:.4f}")

# Visualize some images from the validation set
num_images_to_visualize = 3

with torch.no_grad():
    model.eval()
    for i, (image, mask) in enumerate(val_loader):
        if i >= num_images_to_visualize:
            break

        image = image.to(device)
        outputs = model(image)
        prediction = torch.sigmoid(outputs)

        visualize_images(image[0], mask[0], prediction[0])
# Out:
# Loaded 201 entries from JSON file.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Average IoU for the validation set: 1.0000
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Test the model and calculate IoU for the test set
root_dir = 'TEST'
json_file_path = os.path.join(root_dir, "annotations_test.json")

test_dataset = BrainTumorDataset(json_file_path, root_dir, image_transform=image_transform, mask_transform=mask_transform)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False)

iou_scores = []

with torch.no_grad():
    model.eval()
    for images, masks in test_loader:
        images = images.to(device)
        masks = masks.to(device)

        outputs = model(images)
        predictions = torch.sigmoid(outputs)

        for i in range(len(images)):
            iou = calculate_iou(predictions[i], masks[i])
            iou_scores.append(iou)

average_iou = sum(iou_scores) / len(iou_scores)
print(f"Average IoU for the test set: {average_iou:.4f}")

# Visualize some images from the test set
num_images_to_visualize = 3

with torch.no_grad():
    model.eval()
    for i, (image, mask) in enumerate(test_loader):
        if i >= num_images_to_visualize:
            break

        image = image.to(device)
        outputs = model(image)
        prediction = torch.sigmoid(outputs)

        visualize_images(image[0], mask[0], prediction[0])
# Out:
# Loaded 100 entries from JSON file.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Average IoU for the test set: 1.0000
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
